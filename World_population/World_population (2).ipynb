# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.subplots as sp
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>

# %%
wp = pd.read_csv(r"C:\\Users\\AMITESH\\OneDrive\\Desktop\\World_population\\world_population.csv", encoding="latin1")
wp.head()
wp.shape
wp.isnull().sum()
print(f'Amount of Duplicates:{wp.duplicated().sum()}')
wp.columns
# Out:
# Amount of Duplicates:0
# Index(['Rank', 'Country/Territory', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (kmÃÂÃÂ²)', 'Density (per kmÃÂÃÂ²)',
#        'Growth Rate', 'World Population Percentage', 'Area per Person',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
#        'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43',
#        'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47',
#        'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51',
#        'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55',
#        'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59',
#        'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63',
#        'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67',
#        'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71',
#        'Unnamed: 72', 'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75',
#        'Unnamed: 76', 'Unnamed: 77'],
#       dtype='str')

# %%
wp.sort_values(by = 'Country/Territory',ascending=True)
# Out:
#      Rank  Country/Territory Continent  2022 Population  2020 Population  \
# 0      36        Afghanistan      Asia         41128771         38972230
# 1     138            Albania    Europe          2842321          2866849
# 2      34            Algeria    Africa         44903225         43451666
# 3     213     American Samoa   Oceania            44273            46189
# 4     203            Andorra    Europe            79824            77700
# ..    ...                ...       ...              ...              ...
# 229   226  Wallis and Futuna   Oceania            11572            11655
# 230   172     Western Sahara    Africa           575986           556048
# 231    46              Yemen      Asia         33696614         32284046
# 232    63             Zambia    Africa         20017675         18927715
# 233    74           Zimbabwe    Africa         16320537         15669666
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# 0           33753499         28189672         19542982         10694796
# 1            2882481          2913399          3182021          3295066
# 2           39543154         35856344         30774621         25518074
# 3              51368            54849            58230            47818
# 4              71746            71519            66097            53569
# ..               ...              ...              ...              ...
# 229            12182            13142            14723            13454
# 230           491824           413296           270375           178529
# 231         28516545         24743946         18628700         13375121
# 232         16248230         13792086          9891136          7686401
# 233         14154937         12839771         11834676         10113893
#
#      1980 Population  ...  Unnamed: 68  Unnamed: 69  Unnamed: 70  Unnamed: 71  \
# 0           12486631  ...          NaN          NaN          NaN          NaN
# 1            2941651  ...          NaN          NaN          NaN          NaN
# 2           18739378  ...          NaN          NaN          NaN          NaN
# 3              32886  ...          NaN          NaN          NaN          NaN
# 4              35611  ...          NaN          NaN          NaN          NaN
# ..               ...  ...          ...          ...          ...          ...
# 229            11315  ...          NaN          NaN          NaN          NaN
# 230           116775  ...          NaN          NaN          NaN          NaN
# 231          9204938  ...          NaN          NaN          NaN          NaN
# 232          5720438  ...          NaN          NaN          NaN          NaN
# 233          7049926  ...          NaN          NaN          NaN          NaN
#
#      Unnamed: 72  Unnamed: 73  Unnamed: 74  Unnamed: 75  Unnamed: 76  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 229          NaN          NaN          NaN          NaN          NaN
# 230          NaN          NaN          NaN          NaN          NaN
# 231          NaN          NaN          NaN          NaN          NaN
# 232          NaN          NaN          NaN          NaN          NaN
# 233          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 77
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 229          NaN
# 230          NaN
# 231          NaN
# 232          NaN
# 233          NaN
#
# [234 rows x 78 columns]

# %%
wp.isnull().sum()
# Out:
# Rank                   0
# Country/Territory      0
# Continent              0
# 2022 Population        0
# 2020 Population        0
#                     ...
# Unnamed: 73          234
# Unnamed: 74          234
# Unnamed: 75          234
# Unnamed: 76          234
# Unnamed: 77          234
# Length: 78, dtype: int64

# %%
wp.drop(["CCA3","Capital"],axis=1,inplace=True, errors='ignore')

# %%
countries_by_continent = wp.groupby('Continent').size().reset_index(name='count')

# %%
wp.head()
wp.tail()
custom_palette = ['#0b3d91', '#e0f7fa', '#228b22', '#1e90ff', '#8B4513', '#D2691E',
'#DAA520', '#556B2F']

fig= px.bar(countries_by_continent,
            x='Continent',
            y='count',
            color='Continent',
            text='count',
            title='Number of Countires by Contitnent',
           color_discrete_sequence = custom_palette )

# %%
wp["Rank"]
# Out:
# 0       36
# 1      138
# 2       34
# 3      213
# 4      203
#       ...
# 229    226
# 230    172
# 231     46
# 232     63
# 233     74
# Name: Rank, Length: 234, dtype: int64

# %%
wp.head().sort_values(by = "Country/Territory",ascending= False)
# Out:
#    Rank Country/Territory Continent  2022 Population  2020 Population  \
# 4   203           Andorra    Europe            79824            77700
# 3   213    American Samoa   Oceania            44273            46189
# 2    34           Algeria    Africa         44903225         43451666
# 1   138           Albania    Europe          2842321          2866849
# 0    36       Afghanistan      Asia         41128771         38972230
#
#    2015 Population  2010 Population  2000 Population  1990 Population  \
# 4            71746            71519            66097            53569
# 3            51368            54849            58230            47818
# 2         39543154         35856344         30774621         25518074
# 1          2882481          2913399          3182021          3295066
# 0         33753499         28189672         19542982         10694796
#
#    1980 Population  ...  Unnamed: 68  Unnamed: 69  Unnamed: 70  Unnamed: 71  \
# 4            35611  ...          NaN          NaN          NaN          NaN
# 3            32886  ...          NaN          NaN          NaN          NaN
# 2         18739378  ...          NaN          NaN          NaN          NaN
# 1          2941651  ...          NaN          NaN          NaN          NaN
# 0         12486631  ...          NaN          NaN          NaN          NaN
#
#    Unnamed: 72  Unnamed: 73  Unnamed: 74  Unnamed: 75  Unnamed: 76  \
# 4          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 0          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 77
# 4          NaN
# 3          NaN
# 2          NaN
# 1          NaN
# 0          NaN
#
# [5 rows x 78 columns]

# %%
wp.tail()
# Out:
#      Rank  Country/Territory Continent  2022 Population  2020 Population  \
# 229   226  Wallis and Futuna   Oceania            11572            11655
# 230   172     Western Sahara    Africa           575986           556048
# 231    46              Yemen      Asia         33696614         32284046
# 232    63             Zambia    Africa         20017675         18927715
# 233    74           Zimbabwe    Africa         16320537         15669666
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# 229            12182            13142            14723            13454
# 230           491824           413296           270375           178529
# 231         28516545         24743946         18628700         13375121
# 232         16248230         13792086          9891136          7686401
# 233         14154937         12839771         11834676         10113893
#
#      1980 Population  ...  Unnamed: 68  Unnamed: 69  Unnamed: 70  Unnamed: 71  \
# 229            11315  ...          NaN          NaN          NaN          NaN
# 230           116775  ...          NaN          NaN          NaN          NaN
# 231          9204938  ...          NaN          NaN          NaN          NaN
# 232          5720438  ...          NaN          NaN          NaN          NaN
# 233          7049926  ...          NaN          NaN          NaN          NaN
#
#      Unnamed: 72  Unnamed: 73  Unnamed: 74  Unnamed: 75  Unnamed: 76  \
# 229          NaN          NaN          NaN          NaN          NaN
# 230          NaN          NaN          NaN          NaN          NaN
# 231          NaN          NaN          NaN          NaN          NaN
# 232          NaN          NaN          NaN          NaN          NaN
# 233          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 77
# 229          NaN
# 230          NaN
# 231          NaN
# 232          NaN
# 233          NaN
#
# [5 rows x 78 columns]

# %%
wp.tail().sort_values(by='Country/Territory',ascending=True)
# Out:
#      Rank  Country/Territory Continent  2022 Population  2020 Population  \
# 229   226  Wallis and Futuna   Oceania            11572            11655
# 230   172     Western Sahara    Africa           575986           556048
# 231    46              Yemen      Asia         33696614         32284046
# 232    63             Zambia    Africa         20017675         18927715
# 233    74           Zimbabwe    Africa         16320537         15669666
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# 229            12182            13142            14723            13454
# 230           491824           413296           270375           178529
# 231         28516545         24743946         18628700         13375121
# 232         16248230         13792086          9891136          7686401
# 233         14154937         12839771         11834676         10113893
#
#      1980 Population  ...  Unnamed: 68  Unnamed: 69  Unnamed: 70  Unnamed: 71  \
# 229            11315  ...          NaN          NaN          NaN          NaN
# 230           116775  ...          NaN          NaN          NaN          NaN
# 231          9204938  ...          NaN          NaN          NaN          NaN
# 232          5720438  ...          NaN          NaN          NaN          NaN
# 233          7049926  ...          NaN          NaN          NaN          NaN
#
#      Unnamed: 72  Unnamed: 73  Unnamed: 74  Unnamed: 75  Unnamed: 76  \
# 229          NaN          NaN          NaN          NaN          NaN
# 230          NaN          NaN          NaN          NaN          NaN
# 231          NaN          NaN          NaN          NaN          NaN
# 232          NaN          NaN          NaN          NaN          NaN
# 233          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 77
# 229          NaN
# 230          NaN
# 231          NaN
# 232          NaN
# 233          NaN
#
# [5 rows x 78 columns]

# %%
pop_22 = wp['2022 Population'].sum()
pop_70 = wp['1970 Population'].sum()

pop_22 - pop_70
# Out:
# np.int64(4279276381)

# %%
countries_by_continent = wp["Continent"].value_counts().reset_index()
countries_by_continent
# Out:
#        Continent  count
# 0         Africa     57
# 1           Asia     50
# 2         Europe     50
# 3  North America     40
# 4        Oceania     23
# 5  South America     14

# %%
wp.groupby(by="Continent").count()
# Out:
#                Rank  Country/Territory  2022 Population  2020 Population  \
# Continent
# Africa           57                 57               57               57
# Asia             50                 50               50               50
# Europe           50                 50               50               50
# North America    40                 40               40               40
# Oceania          23                 23               23               23
# South America    14                 14               14               14
#
#                2015 Population  2010 Population  2000 Population  \
# Continent
# Africa                      57               57               57
# Asia                        50               50               50
# Europe                      50               50               50
# North America               40               40               40
# Oceania                     23               23               23
# South America               14               14               14
#
#                1990 Population  1980 Population  1970 Population  ...  \
# Continent                                                         ...
# Africa                      57               57               57  ...
# Asia                        50               50               50  ...
# Europe                      50               50               50  ...
# North America               40               40               40  ...
# Oceania                     23               23               23  ...
# South America               14               14               14  ...
#
#                Unnamed: 68  Unnamed: 69  Unnamed: 70  Unnamed: 71  \
# Continent
# Africa                   0            0            0            0
# Asia                     0            0            0            0
# Europe                   0            0            0            0
# North America            0            0            0            0
# Oceania                  0            0            0            0
# South America            0            0            0            0
#
#                Unnamed: 72  Unnamed: 73  Unnamed: 74  Unnamed: 75  \
# Continent
# Africa                   0            0            0            0
# Asia                     0            0            0            0
# Europe                   0            0            0            0
# North America            0            0            0            0
# Oceania                  0            0            0            0
# South America            0            0            0            0
#
#                Unnamed: 76  Unnamed: 77
# Continent
# Africa                   0            0
# Asia                     0            0
# Europe                   0            0
# North America            0            0
# Oceania                  0            0
# South America            0            0
#
# [6 rows x 77 columns]

# %% [markdown]
# ### Create the bar chart

# %%
fig= px.bar(countries_by_continent,
            x='Continent',
            y='count',
            color='Continent',
            text='count',
            title='Number of Countires by Contitnent',
           color_discrete_sequence = custom_palette )

# %%
fig.update_layout(
xaxis_title='Continents',
yaxis_title='Number of Countries',
plot_bgcolor='rgba(0,0,0,0)',
font_family='Arial',
title_font_size=20 )
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="53cab54f-5b25-45e6-8272-da2bac01a1ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("53cab54f-5b25-45e6-8272-da2bac01a1ec")) {                    Plotly.newPlot(                        "53cab54f-5b25-45e6-8272-da2bac01a1ec",                        [{"hovertemplate":"Continent=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Africa","marker":{"color":"#0b3d91","pattern":{"shape":""}},"name":"Africa","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAACATEA="},"textposition":"auto","x":["Africa"],"xaxis":"x","y":{"dtype":"i1","bdata":"OQ=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Continent=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","marker":{"color":"#e0f7fa","pattern":{"shape":""}},"name":"Asia","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAASUA="},"textposition":"auto","x":["Asia"],"xaxis":"x","y":{"dtype":"i1","bdata":"Mg=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Continent=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe","marker":{"color":"#228b22","pattern":{"shape":""}},"name":"Europe","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAASUA="},"textposition":"auto","x":["Europe"],"xaxis":"x","y":{"dtype":"i1","bdata":"Mg=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Continent=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#1e90ff","pattern":{"shape":""}},"name":"North America","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAREA="},"textposition":"auto","x":["North America"],"xaxis":"x","y":{"dtype":"i1","bdata":"KA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Continent=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oceania","marker":{"color":"#8B4513","pattern":{"shape":""}},"name":"Oceania","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAN0A="},"textposition":"auto","x":["Oceania"],"xaxis":"x","y":{"dtype":"i1","bdata":"Fw=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Continent=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South America","marker":{"color":"#D2691E","pattern":{"shape":""}},"name":"South America","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAALEA="},"textposition":"auto","x":["South America"],"xaxis":"x","y":{"dtype":"i1","bdata":"Dg=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333333 ...

# %%
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="0c1c7652-cbba-4986-b020-e7353c829c8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0c1c7652-cbba-4986-b020-e7353c829c8c")) {                    Plotly.newPlot(                        "0c1c7652-cbba-4986-b020-e7353c829c8c",                        [{"hovertemplate":"Continent=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Africa","marker":{"color":"#0b3d91","pattern":{"shape":""}},"name":"Africa","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAACATEA="},"textposition":"auto","x":["Africa"],"xaxis":"x","y":{"dtype":"i1","bdata":"OQ=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Continent=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","marker":{"color":"#e0f7fa","pattern":{"shape":""}},"name":"Asia","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAASUA="},"textposition":"auto","x":["Asia"],"xaxis":"x","y":{"dtype":"i1","bdata":"Mg=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Continent=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe","marker":{"color":"#228b22","pattern":{"shape":""}},"name":"Europe","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAASUA="},"textposition":"auto","x":["Europe"],"xaxis":"x","y":{"dtype":"i1","bdata":"Mg=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Continent=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#1e90ff","pattern":{"shape":""}},"name":"North America","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAREA="},"textposition":"auto","x":["North America"],"xaxis":"x","y":{"dtype":"i1","bdata":"KA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Continent=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oceania","marker":{"color":"#8B4513","pattern":{"shape":""}},"name":"Oceania","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAN0A="},"textposition":"auto","x":["Oceania"],"xaxis":"x","y":{"dtype":"i1","bdata":"Fw=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Continent=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South America","marker":{"color":"#D2691E","pattern":{"shape":""}},"name":"South America","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAALEA="},"textposition":"auto","x":["South America"],"xaxis":"x","y":{"dtype":"i1","bdata":"Dg=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333333 ...

# %%
continent_population_percentage = wp.groupby('Continent')['World Population Percentage'].sum().reset_index()
continent_population_percentage
# Out:
#        Continent  World Population Percentage
# 0         Africa                        17.87
# 1           Asia                        59.19
# 2         Europe                         9.33
# 3  North America                         7.51
# 4        Oceania                         0.55
# 5  South America                         5.48

# %%
fig = go.Figure(data=[go.Pie(labels=continent_population_percentage['Continent'],
values=continent_population_percentage['World Population Percentage'])])

# %%
fig.update_layout(
title='World Population Percentage by Continent',
template='plotly',
paper_bgcolor='rgba(255,255,255,0)', 
plot_bgcolor='rgba(255,255,255,0)' 
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="dd92d957-119a-4733-9477-60c8ce0c9cb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("dd92d957-119a-4733-9477-60c8ce0c9cb1")) {                    Plotly.newPlot(                        "dd92d957-119a-4733-9477-60c8ce0c9cb1",                        [{"labels":["Africa","Asia","Europe","North America","Oceania","South America"],"values":{"dtype":"f8","bdata":"H4XrUbjeMUC4HoXrUZhNQClcj8L1qCJACtejcD0KHkCamZmZmZnhP+tRuB6F6xVA"},"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scattermap":[{"type":"scattermap","marker":{"colorbar":{"outlinewidth":0,"ticks":""} ...

# %%
fig.update_traces(marker=dict(colors=custom_palette, line=dict(color='#FFFFFF',
width=1)))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="db33ed23-42d7-406d-80f4-dbf962e73189" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("db33ed23-42d7-406d-80f4-dbf962e73189")) {                    Plotly.newPlot(                        "db33ed23-42d7-406d-80f4-dbf962e73189",                        [{"labels":["Africa","Asia","Europe","North America","Oceania","South America"],"values":{"dtype":"f8","bdata":"H4XrUbjeMUC4HoXrUZhNQClcj8L1qCJACtejcD0KHkCamZmZmZnhP+tRuB6F6xVA"},"type":"pie","marker":{"line":{"color":"#FFFFFF","width":1},"colors":["#0b3d91","#e0f7fa","#228b22","#1e90ff","#8B4513","#D2691E","#DAA520","#556B2F"]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""}}, ...

# %% [markdown]
# ### Melt the DataFrame to have a long format

# %%
wp_melted = wp.melt(id_vars=['Continent'],
value_vars=['2022 Population', '2020 Population', '2015 Population','2010 Population', '2000 Population', '1990 Population','1980 Population',
            '1970 Population'],
var_name='Year',
value_name='Population')

# %%
wp_melted['Year'] = wp_melted['Year'].str.split().str[0].astype(int)
population_by_continent = wp_melted.groupby(['Continent',
'Year']).sum().reset_index()

# %%
fig = px.line(population_by_continent, x='Year', y='Population', color='Continent',
title='Population Trends by Continent Over Time',
labels={'Population': 'Population', 'Year': 'Year'},
color_discrete_sequence=custom_palette)
fig.update_layout(
template='plotly_white',
xaxis_title='Year',
yaxis_title='Population',
font_family='Arial',
title_font_size=20,
)
fig.update_traces(line=dict(width=3))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="311d6192-a566-4d83-8a5a-05f7aceeb6f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("311d6192-a566-4d83-8a5a-05f7aceeb6f0")) {                    Plotly.newPlot(                        "311d6192-a566-4d83-8a5a-05f7aceeb6f0",                        [{"hovertemplate":"Continent=Africa\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Africa","line":{"color":"#0b3d91","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Africa","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"sge8B8YH0AfaB98H5AfmBw=="},"xaxis":"x","y":{"dtype":"i4","bdata":"\u002fDzIFXmpsxzlZwkm8B\u002fQMKiA5T5qXpdHQjQaUbQvClU="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Continent=Asia\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","line":{"color":"#e0f7fa","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Asia","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"sge8B8YH0AfaB98H5AfmBw=="},"xaxis":"x","y":[2144906290,2635334228,3210563577,3735089604,4220041327,4458250182,4663086535,4721383274],"yaxis":"y","type":"scatter"},{"hovertemplate":"Continent=Europe\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe","line":{"color":"#228b22","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Europe","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"sge8B8YH0AfaB98H5AfmBw=="},"xaxis":"x","y":{"dtype":"i4","bdata":"F5sYJzcgRykdOe8qb05HK+6T2Ct47zIsxOJzLBKISyw="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Continent=North America\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","line":{"color":"#1e90ff","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"North America","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"sge8B8YH0AfaB98H5AfmBw=="},"xaxis":"x","y":{"dtype":"i4","bdata":"bibNEvG18xX5AxwZUNX4HItCWSDqXf8hsVRrI8jKxyM="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Continent=Oceania\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oceania","line":{"color":"#8B4513","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Oceania","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"sge8B8YH0AfaB98H5AfmBw=="},"xaxis":"x","y":{"dtype":"i4","bdata":"zj4pATC8XQEOFJgB+mvcAawkNgJTgWgC8l6eAto7rwI="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Continent=South America\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South America","line":{"color":"#D2691E","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"South America","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"sge8B8YH0AfaB98H5AfmBw=="},"xaxis":"x","y":{"dtype":"i4","bdata":"1COAC05oaQ4vGLYR6v7WFOrlbRc87p8YO6C4GeBKCRo="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f ...

# %%
features=['1970 Population' ,'2020 Population']
for feature in features:
    fig = px.choropleth(wp,
                        locations='Country/Territory',
                        locationmode='country names',
                        color=feature,
                        hover_name='Country/Territory',
                        template='plotly_white',
                        title = feature)
fig.show()
# Out:
# C:\Users\AMITESH\AppData\Local\Temp\ipykernel_15048\195813007.py:3: DeprecationWarning: The library used by the *country names* `locationmode` option is changing in an upcoming version. Country names in existing plots may not work in the new version. To ensure consistent behavior, consider setting `locationmode` to *ISO-3*.
#   fig = px.choropleth(wp,
# C:\Users\AMITESH\AppData\Local\Temp\ipykernel_15048\195813007.py:3: DeprecationWarning: The library used by the *country names* `locationmode` option is changing in an upcoming version. Country names in existing plots may not work in the new version. To ensure consistent behavior, consider setting `locationmode` to *ISO-3*.
#   fig = px.choropleth(wp,
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="19d74208-3f76-4fc8-a75c-b8aa928ee250" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("19d74208-3f76-4fc8-a75c-b8aa928ee250")) {                    Plotly.newPlot(                        "19d74208-3f76-4fc8-a75c-b8aa928ee250",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=%{location}\u003cbr\u003e2020 Population=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Albania","Algeria","American Samoa","Andorra","Angola","Anguilla","Antigua and Barbuda","Argentina","Armenia","Aruba","Australia","Austria","Azerbaijan","Bahamas","Bahrain","Bangladesh","Barbados","Belarus","Belgium","Belize","Benin","Bermuda","Bhutan","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","British Virgin Islands","Brunei","Bulgaria","Burkina Faso","Burundi","Cambodia","Cameroon","Canada","Cape Verde","Cayman Islands","Central African Republic","Chad","Chile","China","Colombia","Comoros","Cook Islands","Costa Rica","Croatia","Cuba","Curacao","Cyprus","Czech Republic","Denmark","Djibouti","Dominica","Dominican Republic","DR Congo","Ecuador","Egypt","El Salvador","Equatorial Guinea","Eritrea","Estonia","Eswatini","Ethiopia","Falkland Islands","Faroe Islands","Fiji","Finland","France","French Guiana","French Polynesia","Gabon","Gambia","Georgia","Germany","Ghana","Gibraltar","Greece","Greenland","Grenada","Guadeloupe","Guam","Guatemala","Guernsey","Guinea","Guinea-Bissau","Guyana","Haiti","Honduras","Hong Kong","Hungary","Iceland","India","Indonesia","Iran","Iraq","Ireland","Isle of Man","Israel","Italy","Ivory Coast","Jamaica","Japan","Jersey","Jordan","Kazakhstan","Kenya","Kiribati","Kuwait","Kyrgyzstan","Laos","Latvia","Lebanon","Lesotho","Liberia","Libya","Liechtenstein","Lithuania","Luxembourg","Macau","Madagascar","Malawi","Malaysia","Maldives","Mali","Malta","Marshall Islands","Martinique","Mauritania","Mauritius","Mayotte","Mexico","Micronesia","Moldova","Monaco","Mongolia","Montenegro","Montserrat","Morocco","Mozambique","Myanmar","Namibia","Nauru","Nepal","Netherlands","New Caledonia","New Zealand","Nicaragua","Niger","Nigeria","Niue","North Korea","North Macedonia","Northern Mariana Islands","Norway","Oman","Pakistan","Palau","Palestine","Panama","Papua New Guinea","Paraguay","Peru","Philippines","Poland","Portugal","Puerto Rico","Qatar","Republic of the Congo","Reunion","Romania","Russia","Rwanda","Saint Barthelemy","Saint Kitts and Nevis","Saint Lucia","Saint Martin","Saint Pierre and Miquelon","Saint Vincent and the Grenadines","Samoa","San Marino","Sao Tome and Principe","Saudi Arabia","Senegal","Serbia","Seychelles","Sierra Leone","Singapore","Sint Maarten","Slovakia","Slovenia","Solomon Islands","Somalia","South Africa","South Korea","South Sudan","Spain","Sri Lanka","Sudan","Suriname","Sweden","Switzerland","Syria","Taiwan","Tajikistan","Tanzania","Thailand","Timor-Leste","Togo","Tokelau","Tonga","Trinidad and Tobago","Tunisia","Turkey","Turkmenistan","Turks and Caicos Islands","Tuvalu","Uganda","Ukraine","United Arab Emirates","United Kingdom","United States","United States Virgin Islands","Uruguay","Uzbekistan","Vanuatu","Vatican City","Venezuela","Vietnam","Wallis and Futuna","Western Sahara","Yemen","Zambia","Zimbabwe"],"locationmode":"country names","locations":["Afghanistan","Albania","Algeria","American Samoa","Andorra","Angola","Anguilla","Antigua and Barbuda","Argentina","Armenia","Aruba","Australia","Austria","Azerbaijan","Bahamas","Bahrain","Bangladesh","Barbados","Belarus","Belgium","Belize","Benin","Bermuda","Bhutan","Bolivia","Bos ...

# %%
growth = (wp.groupby(by='Country/Territory')['2022 Population'].sum()-wp.groupby(by='Country/Territory')
          ['1970 Population'].sum()).sort_values(ascending=False).head(8)

fig=px.bar(x=growth.index,
y=growth.values,
text=growth.values,
color=growth.values,
title='Growth Of Population From 1970 to 2020 (Top 8)',
template='plotly_white')
fig.update_layout(xaxis_title='Country',
yaxis_title='Population Growth')
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="f733fa92-8cda-4edb-8589-d67b3d1ad9ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f733fa92-8cda-4edb-8589-d67b3d1ad9ab")) {                    Plotly.newPlot(                        "f733fa92-8cda-4edb-8589-d67b3d1ad9ab",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"i4","bdata":"QI09Mzdv9iPmsYUKLMG2CTGSjQktIDkIh+8WB2B9LQY="},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"AAAAoMaeyUEAAICbN\u002fvBQQAAAMxjC6VBAAAAWIJto0EAAABiJBujQQAAAFpAcqBBAAAAHL5bnEEAAACA9bWYQQ=="},"textposition":"auto","x":["India","China","Pakistan","Nigeria","Indonesia","United States","Brazil","Bangladesh"],"xaxis":"x","y":{"dtype":"i4","bdata":"QI09Mzdv9iPmsYUKLMG2CTGSjQktIDkIh+8WB2B9LQY="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"ma ...

# %%
top_8_populated_countries_1970 = wp.groupby('Country/Territory')['1970 Population'].sum().sort_values(ascending=False).head(8)
top_8_populated_countries_2022 = wp.groupby('Country/Territory')['2022 Population'].sum().sort_values(ascending=False).head(8)

features = {'top_8_populated_countries_1970': top_8_populated_countries_1970,
'top_8_populated_countries_2022': top_8_populated_countries_2022}
for feature_name, feature_data in features.items():
    year = feature_name.split('_')[-1] 
    fig = px.bar(x=feature_data.index,
                 y=feature_data.values,
                 text=feature_data.values,
                 color=feature_data.values,
                 title=f'Top 8 Most Populated Countries ({year})',
                 template='plotly_white')
    fig.update_layout(xaxis_title='Country',
                      yaxis_title='Population Growth')
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="d305a950-a06b-46c7-a26b-28ff698d5a44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d305a950-a06b-46c7-a26b-28ff698d5a44")) {                    Plotly.newPlot(                        "d305a950-a06b-46c7-a26b-28ff698d5a44",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"i4","bdata":"aVD9VLVYeFTB5CkUG9FrEN5mDg6crAYNWmzVDMQYNAo="},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"AABAGlQ\u002f1UEAAEAtFh7VQQAAAMHkKbRBAAAAG9FrsEEAAAC8zRysQQAAADhZDapBAAAAtNiqqUEAAACIMWikQQ=="},"textposition":"auto","x":["China","India","United States","Indonesia","Pakistan","Nigeria","Brazil","Bangladesh"],"xaxis":"x","y":{"dtype":"i4","bdata":"aVD9VLVYeFTB5CkUG9FrEN5mDg6crAYNWmzVDMQYNAo="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"ma ...

# %%
sorted_df_growth = wp.sort_values(by='Growth Rate', ascending=False)
top_fastest = sorted_df_growth.head(6)
top_slowest = sorted_df_growth.tail(6)

# %%
def plot_population_trends(countries):
    n_cols = 2
    n_rows = (len(countries) + n_cols - 1) // n_cols

# %%
def plot_population_trends(countries):
    
    n_cols = 2
    n_rows = (len(countries) + n_cols - 1) // n_cols

    fig = sp.make_subplots(rows=n_rows, cols=n_cols, subplot_titles=countries,
                           horizontal_spacing=0.1, vertical_spacing=0.1)

    for i, country in enumerate(countries, start=1):
       
        country_wp = wp[wp['Country/Territory'] == country]

       
        country_melted = country_wp .melt(
            id_vars=['Country/Territory'],
            value_vars=['2022 Population', '2020 Population', '2015 Population',
                        '2010 Population', '2000 Population', '1990 Population',
                        '1980 Population', '1970 Population'],
            var_name='Year',
            value_name='Population'
        )

     
        country_melted['Year'] = country_melted['Year'].str.split().str[0].astype(int)

        
        line_fig = px.line(country_melted, x='Year', y='Population',
                           color='Country/Territory',
                           labels={'Population': 'Population', 'Year': 'Year'},
                           color_discrete_sequence=custom_palette)

       
        row = (i - 1) // n_cols + 1
        col = (i - 1) % n_cols + 1

        for trace in line_fig.data:
            fig.add_trace(trace, row=row, col=col)


    fig.update_layout(
        title='Population Trends of Selected Countries Over Time',
        template='plotly_white',
        font_family='Arial',
        title_font_size=20,
        showlegend=False,
        height=600 * n_rows,  
    )
    fig.update_traces(line=dict(width=3))
    fig.update_xaxes(title_text='Year')
    fig.update_yaxes(title_text='Population')
    fig.show()

# %%
fastest = top_fastest[['Country/Territory', 'Growth Rate']].sort_values(by='Growth Rate', ascending=False).reset_index(drop=True)
fastest
plot_population_trends(['Moldova', 'Poland', 'Niger', 'Syria', 'Slovakia', 'DR Congo'])
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="e144888e-bb6e-450f-b858-e145d940258e" class="plotly-graph-div" style="height:1800px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e144888e-bb6e-450f-b858-e145d940258e")) {                    Plotly.newPlot(                        "e144888e-bb6e-450f-b858-e145d940258e",                        [{"hovertemplate":"Country\u002fTerritory=Moldova\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Moldova","line":{"color":"#0b3d91","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Moldova","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5gfkB98H2gfQB8YHvAeyBw=="},"xaxis":"x","y":{"dtype":"i4","bdata":"JPExAC8SLwBMAjIA6h84ALXfQADHXEQASJw+AKSgOAA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country\u002fTerritory=Poland\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Poland","line":{"color":"#0b3d91","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Poland","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5gfkB98H2gfQB8YHvAeyBw=="},"xaxis":"x2","y":{"dtype":"i4","bdata":"+StgAs5eSgI6RkwC6fJMAu+HSwJ\u002f0EQClQMeAn+m7wE="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"Country\u002fTerritory=Niger\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Niger","line":{"color":"#0b3d91","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Niger","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5gfkB98H2gfQB8YHvAeyBw=="},"xaxis":"x3","y":{"dtype":"i4","bdata":"6eaPAUdNcwF8ITMBdwX+AAlZsQDXuX8A+TFeAAxBRwA="},"yaxis":"y3","type":"scatter"},{"hovertemplate":"Country\u002fTerritory=Syria\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Syria","line":{"color":"#0b3d91","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Syria","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5gfkB98H2gfQB8YHvAeyBw=="},"xaxis":"x4","y":{"dtype":"i4","bdata":"wZpRAfP2PAE6DCUBG9hUAcbV+ACkWL0AismHAF9sYAA="},"yaxis":"y4","type":"scatter"},{"hovertemplate":"Country\u002fTerritory=Slovakia\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slovakia","line":{"color":"#0b3d91","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Slovakia","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5gfkB98H2gfQB8YHvAeyBw=="},"xaxis":"x5","y":{"dtype":"i4","bdata":"vRxWAClDUwA8xVIAyFdSALIKUgD5R1AAO+VLAHMDRQA="},"yaxis":"y5","type":"scatter"},{"hovertemplate":"Country\u002fTerritory=DR Congo\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DR Congo","line":{"color":"#0b3d91","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"DR Congo","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5gfkB98H2gfQB8YHvAeyBw=="},"xaxis":"x6","y":{"dtype":"i4","bdata":"pMbmBazTiAWINbAE2Qz1A33T5QJVICUCzoqXAbV9MwE="},"yaxis":"y6","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor" ...

# %%
slowest = top_slowest[['Country/Territory', 'Growth Rate']].sort_values(by='Growth Rate', ascending=False).reset_index(drop=True)
slowest
# Out:
#   Country/Territory  Growth Rate
# 0            Latvia       0.9876
# 1         Lithuania       0.9869
# 2          Bulgaria       0.9849
# 3    American Samoa       0.9831
# 4           Lebanon       0.9816
# 5           Ukraine       0.9120

# %%
plot_population_trends(['Latvia', 'Lithuania', 'Bulgaria', 'American Samoa',
'Lebanon', 'Ukraine'])
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="cc7d102b-a61b-4165-99ea-aedf6cf2d095" class="plotly-graph-div" style="height:1800px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cc7d102b-a61b-4165-99ea-aedf6cf2d095")) {                    Plotly.newPlot(                        "cc7d102b-a61b-4165-99ea-aedf6cf2d095",                        [{"hovertemplate":"Country\u002fTerritory=Latvia\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latvia","line":{"color":"#0b3d91","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Latvia","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5gfkB98H2gfQB8YHvAeyBw=="},"xaxis":"x","y":{"dtype":"i4","bdata":"Gz0cAFzyHAATZR4AGhEgANKBJABvCSkABT8nAOaUJAA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country\u002fTerritory=Lithuania\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lithuania","line":{"color":"#0b3d91","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Lithuania","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5gfkB98H2gfQB8YHvAeyBw=="},"xaxis":"x2","y":{"dtype":"i4","bdata":"Z\u002fYpAKsIKwA1OS0Ay+UvABXtNgB3xDkAtro1AKP7MAA="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"Country\u002fTerritory=Bulgaria\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bulgaria","line":{"color":"#0b3d91","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Bulgaria","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5gfkB98H2gfQB8YHvAeyBw=="},"xaxis":"x3","y":{"dtype":"i4","bdata":"AXxnAGd+agDFh28AUdlzAJuPewAiyYUAfgiJACb3ggA="},"yaxis":"y3","type":"scatter"},{"hovertemplate":"Country\u002fTerritory=American Samoa\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"American Samoa","line":{"color":"#0b3d91","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"American Samoa","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5gfkB98H2gfQB8YHvAeyBw=="},"xaxis":"x4","y":{"dtype":"i4","bdata":"8awAAG20AACoyAAAQdYAAHbjAADKugAAdoAAAMNpAAA="},"yaxis":"y4","type":"scatter"},{"hovertemplate":"Country\u002fTerritory=Lebanon\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lebanon","line":{"color":"#0b3d91","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Lebanon","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5gfkB98H2gfQB8YHvAeyBw=="},"xaxis":"x5","y":{"dtype":"i4","bdata":"S8RTAMtoVgDco2EA2DpMAILtQQDk1TYA9jgtAN9XJAA="},"yaxis":"y5","type":"scatter"},{"hovertemplate":"Country\u002fTerritory=Ukraine\u003cbr\u003eYear=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ukraine","line":{"color":"#0b3d91","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"Ukraine","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5gfkB98H2gfQB8YHvAeyBw=="},"xaxis":"x6","y":{"dtype":"i4","bdata":"68xdAiICngIkYa4CTBG5AovY6QK5MhMDoIr6Au5r0QI="},"yaxis":"y6","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","l ...

# %%
land_by_country = wp.groupby('Country/Territory')[wp.columns[10]].sum().sort_values(ascending=False)
most_land = land_by_country.head(5)
least_land = land_by_country.tail(5)
print(most_land)
print(least_land)
# Out:
# Country/Territory
# China            822534450
# India            557501301
# United States    200328340
# Russia           130093010
# Indonesia        115228394
# Name: 1970 Population, dtype: int64
# Country/Territory
# Niue                5185
# Saint Barthelemy    2417
# Falkland Islands    2274
# Tokelau             1714
# Vatican City         752
# Name: 1970 Population, dtype: int64

# %%
fig = sp.make_subplots(rows=1, cols=2, subplot_titles=("Countries with Most Land", "Countries with Least Land"))
fig.add_trace(go.Bar(x=most_land.index, y=most_land.values, name='Most Land', marker_color=custom_palette[0]), row=1, col=1)
fig.add_trace(go.Bar(x=least_land.index, y=least_land.values, name='Least Land', marker_color=custom_palette[1]), row=1, col=2)
fig.update_layout(title_text="Geographical Distribution of Land Area by Country", showlegend=False, template='plotly_white')
fig.update_yaxes(title_text="Area (km²)", row=1, col=1)
fig.update_yaxes(title_text="Area (km²)", row=1, col=2)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="91907007-b358-40b0-a296-ca80d4c21f5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("91907007-b358-40b0-a296-ca80d4c21f5e")) {                    Plotly.newPlot(                        "91907007-b358-40b0-a296-ca80d4c21f5e",                        [{"marker":{"color":"#0b3d91"},"name":"Most Land","x":["China","India","United States","Russia","Indonesia"],"y":{"dtype":"i4","bdata":"MuEGMXXLOiGUxPAL0g\u002fBB+o+3gY="},"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#e0f7fa"},"name":"Least Land","x":["Niue","Saint Barthelemy","Falkland Islands","Tokelau","Vatican City"],"y":{"dtype":"i2","bdata":"QRRxCeIIsgbwAg=="},"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{" ...

# %%
wp['Area per Person'] = wp[wp.columns[10]] / wp['2022 Population']
country_area_per_person = wp.groupby('Country/Territory')['Area per Person'].sum()
most_land_available = country_area_per_person.sort_values(ascending=False).head(5)
least_land_available = country_area_per_person.sort_values(ascending=False).tail(5)

# %%
fig = sp.make_subplots(rows=1, cols=2, subplot_titles=("Countries with Most Land Available Per Capita",
                                                       "Countries with Least Land Available Per Capita"))
fig.add_trace(go.Bar(x=most_land_available.index, y=most_land_available.values,
                     name='Most Land', marker_color=custom_palette[2]), row=1, col=1)
fig.add_trace(go.Bar(x=least_land_available.index, y=least_land_available.values,
name='Least Land', marker_color=custom_palette[3]), row=1, col=2)
fig.update_layout(title_text="Distribution of Available Land Area by Country Per Capita",
                  showlegend=False,
                  template='plotly_white')
fig.update_yaxes(title_text="Land Available Per Person", row=1, col=1)
fig.update_yaxes(title_text="Land Available Per Person", row=1, col=2)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="d89de652-67b5-4ae5-b5ba-5457b067dbca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d89de652-67b5-4ae5-b5ba-5457b067dbca")) {                    Plotly.newPlot(                        "d89de652-67b5-4ae5-b5ba-5457b067dbca",                        [{"marker":{"color":"#228b22"},"name":"Most Land","x":["Niue","Montserrat","Vatican City","Latvia","Georgia"],"y":{"dtype":"f8","bdata":"imM4faFyBUDgtqCqM8cEQJiXl5eXl\u002fc\u002fx9RjEiO69D\u002ffwv5GNYP0Pw=="},"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#1e90ff"},"name":"Least Land","x":["Djibouti","Turks and Caicos Islands","Mayotte","Qatar","United Arab Emirates"],"y":{"dtype":"f8","bdata":"uRIy3Op8wD+T8K11Wbu\u002fP\u002f9M3YTdxrs\u002f3SCZSgprpj+JhQJcUyqgPw=="},"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo ...

# %%
wp.to_csv('world_population.csv', index=False)
